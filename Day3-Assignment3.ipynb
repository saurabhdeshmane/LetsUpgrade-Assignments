# %% [markdown]
# ## **Assignment3**
#
# Create a dataframe using np.random.randn function with 5 rows and 4 columns, and performs various operations using pandas library

# %%
import pandas as pd
import numpy as np

datafr=pd.DataFrame(np.random.randn(5,4),index=['Row a','Row b','Row c','Row d','Row e'],columns=["Column1","Column2","Column3","Column4"])

# %%
datafr
# Out:
#         Column1   Column2   Column3   Column4
# Row a -0.363804  0.897836  0.509426  0.896264
# Row b  0.410147 -0.093215  0.649641  0.098482
# Row c -0.564690  1.224964  1.333225 -1.581198
# Row d -0.833417  0.935927 -2.179337  0.852677
# Row e -2.000407  2.489198  0.175530 -0.151293

# %%
datafr.head(3)
# Out:
#         Column1   Column2   Column3   Column4
# Row a -0.363804  0.897836  0.509426  0.896264
# Row b  0.410147 -0.093215  0.649641  0.098482
# Row c -0.564690  1.224964  1.333225 -1.581198

# %%
datafr.tail(3)
# Out:
#         Column1   Column2   Column3   Column4
# Row c -0.564690  1.224964  1.333225 -1.581198
# Row d -0.833417  0.935927 -2.179337  0.852677
# Row e -2.000407  2.489198  0.175530 -0.151293

# %%
datafr['Column4']
# Out:
# Row a    0.896264
# Row b    0.098482
# Row c   -1.581198
# Row d    0.852677
# Row e   -0.151293
# Name: Column4, dtype: float64

# %%
datafr[['Column1','Column2']]
# Out:
#         Column1   Column2
# Row a -0.363804  0.897836
# Row b  0.410147 -0.093215
# Row c -0.564690  1.224964
# Row d -0.833417  0.935927
# Row e -2.000407  2.489198

# %%
datafr.loc['Row b']
# Out:
# Column1    0.410147
# Column2   -0.093215
# Column3    0.649641
# Column4    0.098482
# Name: Row b, dtype: float64

# %%
datafr.iloc[1:3,2:4]
# Out:
#         Column3   Column4
# Row b  0.649641  0.098482
# Row c  1.333225 -1.581198

# %%
datafr['Column3'].unique()
# Out:
# array([ 0.50942561,  0.64964067,  1.33322484, -2.17933736,  0.17553038])

# %%
datafr['Column3'].value_counts()
# Out:
#  1.333225    1
# -2.179337    1
#  0.175530    1
#  0.509426    1
#  0.649641    1
# Name: Column3, dtype: int64

# %%
datafr.isnull().sum()
# Out:
# Column1    0
# Column2    0
# Column3    0
# Column4    0
# dtype: int64
